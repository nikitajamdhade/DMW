# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the Dataset
data=pd.read_csv("googleplaystore.csv")

# %%
# Print first Rows only
data.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
# Print the Data Types of Each column
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# Data Cleaning
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data[data.Rating > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data.drop([10472],inplace=True)

# %%
data[10470:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
# 10475      50,000+  Free     0       Everyone            Tools
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# ...

# %%
# Find the missing values in Each Column:
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
# Find the missing values from Rating Column and repalce by Median value
# user Defined function
def impute_median(series):
    return series.fillna(series.median())

# Apply user defined function into Rating Column:
data.Rating=data['Rating'].transform(impute_median)

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
# Find the Null values from Type Column and Replace by Mode
data['Type'].fillna(str(data['Type'].mode().values[0]),inplace=True)

# %%
# Find the Null values from Current Version Column and Replace by Mode
data['Current Ver'].fillna(str(data['Current Ver'].mode().values[0]),inplace=True)

# %%
# Find the Null vaues from Andtroid Ver Column and Replace by Mode
data['Android Ver'].fillna(str(data['Android Ver'].mode().values[0]),inplace=True)

# %%
data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
# Data Transformation
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Rating'}>]], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.2+ MB

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
#Data Integration
#To read 2 datasets 
data=pd.read_csv("t20_matches.csv")
data1=pd.read_csv("t20_series.csv")

# %%
# Print first Rows only
data.head(10)
# Out:
#    match_id  series_id                                      match_details  \
# 0    304744     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1    129610     124121  South Group:Hampshire v Sussex at Southampton-...
# 2    129597     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 3    304745     124121  South Group:Surrey v Middlesex at The Oval- Ju...
# 4    304746     124121  Midlands/Wales/West Group:Worcestershire v Nor...
# 5    304747     124121  Midlands/Wales/West Group:Gloucestershire v Wo...
# 6    304748     124121  South Group:Surrey v Essex at East Molesey- Ju...
# 7    304749     124121  North Group:Yorkshire v Derbyshire at Leeds- J...
# 8    304750     124121  Midlands/Wales/West Group:Glamorgan v Northamp...
# 9    129665     124121  South Group:Kent v Hampshire at Beckenham- Jun...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# ...

# %%
# Print first Rows only
data1.head(10)
# Out:
#                                               series   season     winner  \
# 0                                       Twenty20 Cup     2003     Surrey
# 1       Standard Bank Pro20 Series (in South Africa)  2003/04     Eagles
# 2                          Twenty20 Cup (in England)     2004      Leics
# 3                Twenty-20 Tournament (in Sri Lanka)     2004     Chilaw
# 4                Australia in New Zealand T20I Match  2004/05  Australia
# 5       Standard Bank Pro20 Series (in South Africa)  2004/05     Titans
# 6               ABN-AMRO Twenty-20 Cup (in Pakistan)  2004/05     Wolves
# 7                    Australia in England T20I Match     2005    England
# 8                          Twenty20 Cup (in England)     2005   Somerset
# 9  International 20:20 Club Championship (in Engl...     2005     Wolves
#
#     margin  series_id
# 0      NaN     124121
# 1      NaN     134226
# 2      NaN     134471
# 3      NaN     304926
# 4  1-0 (1)     238218
# 5      NaN     143771
# ...

# %%
#To check NaN values in df1
data1.isna()
# Out:
#      series  season  winner  margin  series_id
# 0     False   False   False    True      False
# 1     False   False   False    True      False
# 2     False   False   False    True      False
# 3     False   False   False    True      False
# 4     False   False   False   False      False
# ..      ...     ...     ...     ...        ...
# 368   False   False   False    True      False
# 369   False   False   False   False      False
# 370   False   False   False   False      False
# 371   False   False   False   False      False
# 372   False   False   False    True      False
#
# [373 rows x 5 columns]

# %%
#To delete the row containing NaN values
data1 = data1.drop(4).head()
data1
# Out:
#                                          series   season  winner margin  \
# 0                                  Twenty20 Cup     2003  Surrey    NaN
# 1  Standard Bank Pro20 Series (in South Africa)  2003/04  Eagles    NaN
# 2                     Twenty20 Cup (in England)     2004   Leics    NaN
# 3           Twenty-20 Tournament (in Sri Lanka)     2004  Chilaw    NaN
# 5  Standard Bank Pro20 Series (in South Africa)  2004/05  Titans    NaN
#
#    series_id
# 0     124121
# 1     134226
# 2     134471
# 3     304926
# 5     143771

# %%
#To delete the row containing NaN values
data = data.drop(3).head()

# %%
data
# Out:
#    match_id  series_id                                      match_details  \
# 0    304744     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1    129610     124121  South Group:Hampshire v Sussex at Southampton-...
# 2    129597     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 4    304746     124121  Midlands/Wales/West Group:Worcestershire v Nor...
# 5    304747     124121  Midlands/Wales/West Group:Gloucestershire v Wo...
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# 1                            Hampshire won by 5 runs
# 2                        Warwickshire won by 19 runs
# 4  Worcestershire won by 1 wicket (with 2 balls r...
# 5  Gloucestershire won by 4 wickets (with 5 balls...
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# ...

# %%
#To integrate/merge two datasets in df3
df3 = pd.concat([data, data1])
df3
# Out:
#    match_id  series_id                                      match_details  \
# 0  304744.0     124121  North Group:Durham v Nottinghamshire at Cheste...
# 1  129610.0     124121  South Group:Hampshire v Sussex at Southampton-...
# 2  129597.0     124121  Midlands/Wales/West Group:Somerset v Warwicksh...
# 4  304746.0     124121  Midlands/Wales/West Group:Worcestershire v Nor...
# 5  304747.0     124121  Midlands/Wales/West Group:Gloucestershire v Wo...
# 0       NaN     124121                                                NaN
# 1       NaN     134226                                                NaN
# 2       NaN     134471                                                NaN
# 3       NaN     304926                                                NaN
# 5       NaN     143771                                                NaN
#
#                                               result  \
# 0   Durham won by 6 wickets (with 5 balls remaining)
# ...

# %%
#Data Reduction
data=pd.read_csv("googleplaystore.csv")

# %%
data.drop('Type',inplace=True,axis=1)

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs Price Content Rating                     Genres  \
# 0     159   19M      10,000+     0       Everyone               Art & Design
# 1     967   14M     500,000+     0       Everyone  Art & Design;Pretend Play
# 2   87510  8.7M   5,000,000+     0       Everyone               Art & Design
# 3  215644   25M  50,000,000+     0           Teen               Art & Design
# 4     967  2.8M     100,000+     0       Everyone    Art & Design;Creativity
#
# ...
